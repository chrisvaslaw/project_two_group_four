# %%
pip install spotipy
# Out:
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time 
from sqlalchemy import create_engine

# %%
client_id = '4c6fc8c6e1c845309509a7e02fdba4f1'
client_secret = 'f1f777a75ba24bff8d216c93244e6380'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids
ids = getTrackIDs('icon233', '37i9dQZF1E9X9yjqH8uBus')

# %%
print(len(ids))
print(ids)
# Out:
# 100
# ...

# %%
track_id = {"track id":ids}

# %%
track_id = pd.DataFrame(track_id)
track_id
# Out:
#                   track id
# 0   7I6YpuvNg6mEzUmvpxY5ro
# 1   2SLN0j6wlPLOa0j59rknYx
# 2   6N3qHjcwly8ZuhE4bPYJAX
# 3   0cF0lQsgZNAMnaydXUMFcE
# 4   7ribfTL7pop284OWo6oICl
# ..                     ...
# 95  786PWkpZ8OMdwgk5Nx3xnf
# 96  0IzwEXmCbVDvB6hEzDaSwG
# 97  6046ubTElltXWIVGb6VUQp
# 98  5Qel1sTrU4LM8HlJSPT2jd
# 99  388t96tJStiXYpJgKcnFtm
#
# [100 rows x 1 columns]

# %%
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
# loop over track ids 
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
df.to_csv("spotify.csv", sep = ',')

# %%
df
# Out:
#                                               name                    album  \
# 0   Love Again (Akinyele Back) [feat. Gangsta Boo]         Run the Jewels 2
# 1                                        Burn Slow                 ELDORADO
# 2                       Get You (feat. Kali Uchis)         Get You - Single
# 3                       Ooh Nah Nah (feat. Masego)                  Her Too
# 4                                            Aisha     OYO (Deluxe Edition)
# ..                                             ...                      ...
# 95                                           Zelie     OYO (Deluxe Edition)
# 96       Modern Love - Single Version [Remastered]  Legacy (Deluxe Edition)
# 97               If I Start to Talk (feat. Dr Sid)   R.E.D (Deluxe Edition)
# 98                                     Truth Hurts              Truth Hurts
# 99                 Love Again (feat. JMSN & Sango)      Songs To Make Up To
#
# ...

# %%
new_df = df[['name', 'artist', 'album', 'energy', 'loudness']].copy()
new_df.head()
# Out:
#                                              name           artist  \
# 0  Love Again (Akinyele Back) [feat. Gangsta Boo]   Run The Jewels
# 1                                       Burn Slow         Ro James
# 2                      Get You (feat. Kali Uchis)    Daniel Caesar
# 3                      Ooh Nah Nah (feat. Masego)              SiR
# 4                                           Aisha  Angelique Kidjo
#
#                   album  energy  loudness
# 0      Run the Jewels 2   0.695    -7.951
# 1              ELDORADO   0.630    -7.068
# 2      Get You - Single   0.295    -8.528
# 3               Her Too   0.273   -11.567
# 4  OYO (Deluxe Edition)   0.277    -9.721

# %%
artist_names = new_df['artist']
artist_ids = []

for names in artist_names:
    result = sp.search(names) 
    uri = result['tracks']['items'][0]['artists'][0]['uri']
    uri_splitter = uri.split(':')
    artist_ids.append(uri_splitter[2])
    
print(artist_ids)
# Out:
# ['4RnBFZRiMLRyZy0AzzTg2C', '7r2oyrNc0YjSC7hZL87V0Y', '1uNFoZAHBGtllmzznpCI3s', '7guDJrEfX3qb6FEbdPA5qi', '3wcj11K77LjEY1PkEazffa', '4XWaILHqySwH1y6LhlYcsb', '02kJSzxNuaWGqwubyUba0Z', '0TnOYISbd1XYRBk9myaseg', '2YZyLoL8N0Wb9xBt1NhZWg', '7r2oyrNc0YjSC7hZL87V0Y', '4qwGe91Bz9K2T8jXTZ815W', '3U3zr5PCRa9ty74uN46iBa', '7e1ICztHM2Sc4JNLxeMXYl', '7r2oyrNc0YjSC7hZL87V0Y', '0uGHltM64FZJWH1uOr8YWU', '1uNFoZAHBGtllmzznpCI3s', '16GcWuvvybAoaHr0NqT8Eh', '3U3zr5PCRa9ty74uN46iBa', '0Xf8oDAJYd2D0k3NLI19OV', '1ybINI1qPiFbwDXamRtwxD', '3ycxRkcZ67ALN3GQJ57Vig', '0Maq4Nk8ZM6keGZjTCXGIH', '3P8PFi9LRirEf3JiEDOHZM', '6jGMq4yGs7aQzuGsMgVgZR', '181bsRPaVXVlUKXrxwZfHK', '2IDLDx25HU1nQMKde4n61a', '1dABGukgZ8XKKOdd2rVSHM', '2cFrymmkijnjDg9SS92EPM', '5K4W6rqBFWDnAN6FQUkS6x', '3kAGStCL3niPp7CrJch3dg', '5ZS223C6JyBfXasXxrRqOk', '2IDLDx25HU1nQMKde4n61a', '6PEMFpe3PTOksdV4ZXUpbE', '3ycxRkcZ67ALN3GQJ57Vig', '7MNEVabc4cs19CbzAFZmXz', '3TVXtAsR1Inumwj472S9r4', '3UjPnt2nRmw10N58bBeNOg', '7kFfY4UjNdNyaeUgLIEbIF', '6TrQLQR8
# ...

# %%
new_df["track id"]= track_id["track id"]
new_df["artist id"] = artist_ids
new_df
# Out:
#                                               name           artist  \
# 0   Love Again (Akinyele Back) [feat. Gangsta Boo]   Run The Jewels
# 1                                        Burn Slow         Ro James
# 2                       Get You (feat. Kali Uchis)    Daniel Caesar
# 3                       Ooh Nah Nah (feat. Masego)              SiR
# 4                                            Aisha  Angelique Kidjo
# ..                                             ...              ...
# 95                                           Zelie  Angelique Kidjo
# 96       Modern Love - Single Version [Remastered]      David Bowie
# 97               If I Start to Talk (feat. Dr Sid)      Tiwa Savage
# 98                                     Truth Hurts            Lizzo
# 99                 Love Again (feat. JMSN & Sango)            Ta-ku
#
#                       album  energy  loudness                track id  \
# 0          Run the Jewels 2   0.695    -7.951  7I6YpuvNg6mEzUmvpxY5ro
# ...

# %%
rds_connection_string = f'postgres:0Pken3is@localhost:5432/project_db'
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['playlist_lawrence', 'playlist_dora']

# %%
new_df.to_sql(name='playlist_dora', con=engine, if_exists='append', index=True)
